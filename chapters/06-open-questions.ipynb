# %% [markdown]
# # Open questions
#
# > Validation should not be an afterthought added by policy teams after
# > deployment.
# >
# > — [@oliphant2026, §5.1]
#
# Neither should interpretation. This walkthrough is a translation, not
# an audit, and the questions here arise from the limits of the written
# form: a document may leave open what an executable substrate must
# decide. Nothing was silently repaired, and, just as important, nothing
# was silently decided. The point of this chapter is that **code is not
# objective; its objectivity is downstream of judgment calls.** Where the
# text corpus did not specify everything an executable specification
# requires, the missing judgments were not mixed into the source
# material. Each gap was flagged and characterized, a named adjudicator
# (mzargham) ruled, and the implementations were derived from those
# rulings.
#
# That chain is itself data. `open-questions/adjudications.ttl` records,
# in RDF, every gap (its problem, where it sits in the pinned source, how
# and when it surfaced, its status), every ruling (the adjudicator's
# words verbatim, attributed and dated), and every implementation that
# resulted. The table is a query over that record:

# %%
import sys; sys.path[:0] = [".", ".."]  # the repo root, from either cwd
import exhibits
exhibits.show_adjudication_record()
# Out:
# <table>
# <thead><tr><th>Gap</th><th>Problem</th><th>Surfaced</th><th>Status</th><th>Resolution</th></tr></thead>
# <tbody>
# <tr><td style="text-align:left"><code>GAP-01 — the type of vendor_risk and the value high</code></td><td style="text-align:left">high is an unquoted symbol; the manifest declares no type or value set for vendor_risk. An executable comparison needs both.</td><td style="text-align:left">2026-09-04: typing the vendor_risk == high comparison during the literal translation of the gates block</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-02 — what a then: clause names</code></td><td style="text-align:left">Whether a then-clause names a state the Op enters, an obligation to be discharged, or an action to be performed is not stated.</td><td style="text-align:left">2026-09-04: typing the four then-clauses: stop_and_escalate is grammatically an action while human_review_required is a predicate</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-03 — the provenance and granularity of confidence</code></td><td style="text-align:left">The manifest never says which Guard produces the confidence value the gate reads, nor whether it is per-output, per-Cog, or per-run.</td><td style="text-align:left">2026-09-04: grounding the confidence variable of GATE-01: three Cogs run in this Op and each could carry its own confidence</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-04 — the semantics of consensus_disagreement</code></td><td style="text-align:left">No definition of the disagreement metric is given: not its range, not what it is computed over, not how two-of-three-must-agree maps to a number comparable with 0.25.</td><td style="text-align:left">2026-09-04: typing the consensus_disagreement &gt; 0.25 comparison; the section 5.5 two-of-three example gave no number</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">5 ruling(s) by mzargham on 2026-09-04, 2026-09-05</td></tr>
# <tr><td style="text-align:left"><code>GAP-05 — who provides the gate variables</code></td><td style="text-align:left">The gate variables have no stated provider; an executable policy needs a citable source for every value it reads.</td><td style="text-align:left">2026-09-04: the adjudicator&#x27;s review of the worked examples: numerical values were appearing without an identified provider</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-06 — aggregate outcome: navigating the rules vs executing</code></td><td style="text-align:left">Navigating the rules successfully and executing are different facts; the flat reading could not distinguish a stopped run from a completed one.</td><td style="text-align:left">2026-09-04: the adjudicator&#x27;s review of the stop-and-escalate worked example: POLICY SATISFIED looked identical for a halted run and a completed one</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-07 — track.include lists final_output unconditionally</code></td><td style="text-align:left">track.include lists final_output unconditionally, but a section 5.2 stopped run transmits nothing to retain.</td><td style="text-align:left">2026-09-04: modeling aggregate outcomes: a noOp run cannot satisfy an unconditional final_output requirement</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">3 ruling(s) by mzargham on 2026-09-04, 2026-09-05</td></tr>
# <tr><td style="text-align:left"><code>GAP-08 — the Op&#x27;s internal wiring topology</code></td><td style="text-align:left">Assembling the Op as components wired along ports requires a dataflow topology the paper never draws.</td><td style="text-align:left">2026-09-04: assembling the Op as components per the GAP-06 directive: which component feeds which is stated nowhere</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-09 — who performs the discharging actions</code></td><td style="text-align:left">One component holds the discharging actions; the manifest names a human for review and approval, the prose names human-or-known-expert judgment for expert review, and only the escalation target&#x27;s actor is unspecified.</td><td style="text-align:left">2026-09-04: the adjudicator&#x27;s review of the walkthrough narration: &#x27;cross to the human actions&#x27; over-read the source</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">2 ruling(s) by mzargham on 2026-09-04</td></tr>
# <tr><td style="text-align:left"><code>GAP-10 — the direction of the gates</code></td><td style="text-align:left">Each manifest gate is written if/then. Whether the converse is intended — whether an obligation may be raised when its condition does NOT hold — is not stated. Under the one-way reading, exactly one state satisfies every gate and system requirement for every possible reading: escalate everything, discharge everything, emit nothing.</td><td style="text-align:left">2026-09-05: second external review: exhaustive enumeration of the requirement set&#x27;s Boolean state space (16 readings x 1024 states) found one reading-independent satisfying state, and every committed counterexample was an under-escalation</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-05</td></tr>
# <tr><td style="text-align:left"><code>GAP-11 — the scale the consensus threshold sits on</code></td><td style="text-align:left">The manifest states one threshold, 0.25, for consensus_disagreement. The three exhibited metrics normalize over different things — dissent-fraction over facts x checkers, both undecodability metrics over facts — so the one number means &#x27;more than a quarter of answers dissented&#x27; under one binding and &#x27;more than a quarter of facts failed to decode&#x27; under the others. A single point of definition concealed three scales.</td><td style="text-align:left">2026-09-05: second external review: reading the denominators off the three implementations against the single ValidationStrategyParameters threshold</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-05</td></tr>
# <tr><td style="text-align:left"><code>GAP-12 — the Track carries the metric&#x27;s input</code></td><td style="text-align:left">The GAP-05 interface ruling delivers provenance for the consensus reading — which service, what was sent, what came back — but not re-derivability: the Track recorded the metric&#x27;s name and its output and never its input, the fact-by-checker answer matrix. No auditor could check that 0.10 is what the named metric returns on this run&#x27;s answers, and the question chapter 4 raises — what would the other bindings have said about this run — could not be asked of the record.</td><td style="text-align:left">2026-09-05: second external review: reading the consensus oracle call in track/run-001.trig against the auditability purpose</td><td style="text-align:left"><code>adjudicated</code></td><td style="text-align:left">1 ruling(s) by mzargham on 2026-09-05</td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## The questions, characterized
#
# The summary compresses; the record does not. For each gap: where it
# sits in the pinned source, what the substrate forced, the readings that
# were considered, and the reading in use:

# %%
exhibits.show_gap_characterizations()
# Out:
# <p style="text-align:left"><strong>GAP-01 — the type of vendor_risk and the value high</strong> [adjudicated]</p>
# <ul>
# <li style="text-align:left"><strong>Locus:</strong> WP §5.6, gates block: <code>- if: vendor_risk == high</code> / <code>then: human_approval_required</code></li>
# <li style="text-align:left"><strong>Problem:</strong> high is an unquoted symbol; the manifest declares no type or value set for vendor_risk. An executable comparison needs both.</li>
# <li style="text-align:left"><strong>Surfaced:</strong> 2026-09-04: typing the vendor_risk == high comparison during the literal translation of the gates block</li>
# <li style="text-align:left"><strong>The substrate forces:</strong> an attribute type and a comparable literal.</li>
# <li style="text-align:left"><strong>Readings considered:</strong> (a) an enumeration (e.g. low / medium / high) declared somewhere upstream, perhaps by the vendor-risk-cog; (b) a free string compared to &quot;high&quot;; (c) an ordered scale with <code>high</code> a threshold on a numeric score.</li>
# <li style="text-align:left"><strong>Reading in use:</strong> (a) — an enumeration {high, low, unknown} (<code>RiskLevel</code> in model/vendor-fraud-review.sysml). Flagged as an interpretation, and as a place where modeling could be enhanced with an actual risk model in the future.</li>
# </ul>
# <p style="text-align:left"><strong>GAP-02 — what a then: clause names</strong> [adjudicated]</p>
# <ul>
# <li style="text-align:left"><strong>Locus:</strong> WP §5.6, gates block: <code>then: human_review_required</code>, <code>then: expert_review_required</code>, <code>then: stop_and_escalate</code>, <code>then: human_approval_required</code>; and §5.2 (&quot;A Gate may allow the Op to continue, pause the workflow, request human approval, escalate to an expert, retry with a different Cog, run additional validation, or stop the Op entirely.&quot;)</li>
# <li style="text-align:left"><strong>Problem:</strong> Whether a then-clause names a state the Op enters, an obligation to be discharged, or an action to be performed is not stated.</li>
# <li style="text-align:left"><strong>Surfaced:</strong> 2026-09-04: typing the four then-clauses: stop_and_escalate is grammatically an action while human_review_required is a predicate</li>
# <li style="text-align:left"><strong>The substrate forces:</strong> one ontological kind per identifier before it can be constrained or queried.</li>
# <li style="text-align:left"><strong>Readings considered:</strong> (a) states of the Op instance; (b) obligations whose discharge the Track must evidence; (c) invocations of workflow actions.</li>
# <li style="text-align:left"><strong>Reading in use:</strong> decomposed, no hybrids. State, obligation (a required action, abstract, not yet materialized), and concrete action are distinct: state implies obligation (the GATE requirements); a concrete action discharges the obligation and must also mutate state (the SYSTEM-01 requirement in the model; vfr:Obligation / vfr:discharges / prov:generated in the Track, enforced by shapes/track.shapes.ttl).</li>
# </ul>
# <p style="text-align:left"><strong>GAP-03 — the provenance and granularity of confidence</strong> [adjudicated]</p>
# <ul>
# <li style="text-align:left"><strong>Locus:</strong> WP §5.6: <code>- confidence-guard</code> (in_flight) and <code>- if: confidence &lt; 0.80</code>; §5.1 lists &quot;whether confidence is too low for autonomous action&quot; as something a Guard can check.</li>
# <li style="text-align:left"><strong>Problem:</strong> The manifest never says which Guard produces the confidence value the gate reads, nor whether it is per-output, per-Cog, or per-run.</li>
# <li style="text-align:left"><strong>Surfaced:</strong> 2026-09-04: grounding the confidence variable of GATE-01: three Cogs run in this Op and each could carry its own confidence</li>
# <li style="text-align:left"><strong>The substrate forces:</strong> one referent for the gate&#x27;s variable.</li>
# <li style="text-align:left"><strong>Readings considered:</strong> (a) the minimum across Cog outputs; (b) the invoice-extraction Cog&#x27;s confidence specifically (the §5.2 running-example sentence speaks of &quot;low extraction confidence&quot;); (c) a distinct confidence per Gate evaluation.</li>
# <li style="text-align:left"><strong>Reading in use:</strong> a confidence level enumeration {high, low, unknown} alongside the raw scalar, bound at the manifest&#x27;s 0.80 boundary (<code>ConfidenceLevel</code> and INTERFACE-01 in model/vendor-fraud-review.sysml). The simplified scheme serves as an interface contract with the guard that produces it; likely requires its own confidence model eventually — noted for future enrichment.</li>
# </ul>
# <p style="text-align:left"><strong>GAP-04 — the semantics of consensus_disagreement</strong> [adjudicated]</p>
# <ul>
# <li style="text-align:left"><strong>Locus:</strong> WP §5.6: <code>- if: consensus_disagreement &gt; 0.25</code>; §5.5 Consensus row (&quot;Three Cogs classify a document and two must agree; outlier extractions flagged; …&quot;).</li>
# <li style="text-align:left"><strong>Problem:</strong> No definition of the disagreement metric is given: not its range, not what it is computed over, not how two-of-three-must-agree maps to a number comparable with 0.25.</li>
# <li style="text-align:left"><strong>Surfaced:</strong> 2026-09-04: typing the consensus_disagreement &gt; 0.25 comparison; the section 5.5 two-of-three example gave no number</li>
# <li style="text-align:left"><strong>The substrate forces:</strong> a typed quantity for the comparison to execute.</li>
# <li style="text-align:left"><strong>Readings considered:</strong> (a) fraction of dissenting Cogs; (b) 1 − pairwise agreement rate; (c) a task-specific divergence score normalized to [0, 1].</li>
# <li style="text-align:left"><strong>Reading in use:</strong> deliberately open, with the openness made structural. The metric&#x27;s TYPE is fixed (a fact-by-checker answer matrix of nullable Booleans mapped to a scalar in [0, 1] against the 0.25 threshold — the abstract ConsensusInadequacyMetric in the model, with the codomain a checked constraint, TYPE-01; the class is split along one axiom into a DisagreementMetric branch, monotone in dissent and saturating at unanimous dissent, and an UndecodabilityMetric branch, which is neither — class split, 2026-09-05), and three type-satisfying alternatives with different semantics are exhibited (dissent-fraction, strict-quorum-undecodable, erasure-aware-undecodable), evaluated on the same answer matrix in chapter 4 of the walkthrough, where they disagree about whether the gate fires. No metric is chosen: a correctly constructed policy is not the same as a fit-for-purpose policy, and what is right for the job here is an open algorithmic policy design question — unlikely to have a unique correct answer, with many viable answers carrying different implications on incentives, and not limited to these three. The comparator oracle&#x27;s metric slot is typed and unbound; a deployment binds it, and the Track records which metric a run used (recording is not endorsing).</li>
# <li style="text-align:left"><strong>Notes:</strong> <strong>Earlier deferral note (2026-09-04):</strong> revisit when the compared spaces are known; if the comparison reduces to yes/no/cantTell facts, an error-correcting-code style interpretation becomes available — that reduction is now the type signature.<br/><strong>Type clarified (2026-09-04, ruling logged in this record):</strong> the answer base type is a nullable Boolean, for type-checking support. Given a datum as context, and irrespective of which Cog produced it, a checker answers &quot;do you agree with the datum?&quot;: True = agree, False = disagree, null = cannot tell (the Track&#x27;s earl:cantTell). Checkers are factored apart from generators: a Cog that produced a datum may itself answer False when asked whether it stands; the optional convention that a producer files True about its own output is NOT assumed.<br

# %% [markdown]
# ## The rulings, verbatim
#
# Every ruling and note, in the order they were made — the adjudicator's
# words exactly (original spelling preserved; these are quotations, not
# copy), and, where an external reviewer examined this repository, the
# findings paraphrased and attributed — each followed by what changed in
# the substrate as a result:

# %%
exhibits.show_rulings_log()
# Out:
# <p style="text-align:left"><strong>1. GAP-01</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">convert it to an enum with high, low and unknown. and flag it as an interpretation and a place where modeling could be enhanced with an actual risk model in the future.</blockquote>
# <p style="text-align:left"><em>Changed:</em> <code>vendorRisk</code> retyped from String to <code>enum def RiskLevel {high, low, unknown}</code>; GATE-04 compares against <code>RiskLevel::high</code>; the enum&#x27;s doc comment flags the interpretation and the future risk-model enhancement point (model/vendor-fraud-review.sysml).</p>
# <p style="text-align:left"><strong>2. GAP-02</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">needs to be decomposed. we don&#x27;t want hybrids, state, obligation (is a required action that is abstract, not yet materialized) whereas a concrete action can discharge an obligation; these are distinct concepts. if state x implies obligation, then the action which discharges that obligation must also mutate state.</blockquote>
# <p style="text-align:left"><em>Changed:</em> the hybrid reading was replaced by a three-way decomposition. Model: GATE requirements raise obligations from state; a requirement (now SYSTEM-01) demands every raised obligation be discharged; discharge attributes added; the counterexample exhibits both failure kinds (gate fired with no obligation raised; obligation raised with no discharge). Track: <code>vfr:Obligation</code> nodes raised by gate decisions; the approval <code>vfr:discharges</code> them and <code>prov:generated</code> the post-review case state. Shapes: obligations must be discharged; a discharging action must be named, rationaled, and must record the state it generated. Queries: governance reports undischarged obligations; auditability traverses gate to obligation to discharging action.</p>
# <p style="text-align:left"><strong>3. GAP-03</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">confidence level treated with enum similar to risk. likely requires its own confidence model eventually but here can serve as an interface contract with a simplified scheme. notes on future enrichment</blockquote>
# <p style="text-align:left"><em>Changed:</em> <code>enum def ConfidenceLevel {high, low, unknown}</code> added alongside the raw scalar; INTERFACE-01 binds the two at the manifest&#x27;s 0.80 boundary as the interface contract; doc comments carry the future-enrichment note (model/vendor-fraud-review.sysml).</p>
# <p style="text-align:left"><strong>4. GAP-04 (deferral)</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">we need to come back to this when we have a better sense of what the spaces are being compared. is this bit-exact comparison, semantic distance or some other metrics. if we can get this tighter we can treat it as error correcting code style interpretation. this requires we can reduce to yes/no/canttell facts we&#x27;re agreeing or disagreeing on</blockquote>
# <p style="text-align:left"><em>Changed:</em> nothing in the substrate; the entry remained open with the ruling&#x27;s direction recorded as an adjudication note.</p>
# <p style="text-align:left"><strong>5. GAP-05</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">where ever we need a number we must assume an oracle that can provide it and have an identity for that oracle, and be able to precisely cite it. that means we need to know what service we called what payload we sent, what response code we got and what response we got. our system needs these answers to apply its policies but is not itself the provider of these numbers. so these make up interface contract.</blockquote>
# <p style="text-align:left"><em>Changed:</em> the Track gained an interface graph: four identified oracle services, one cited call per gate variable (request payload, response code, response payload), and a reading node per value. Gate decisions now cite the reading they evaluated. Shapes refuse unsourced readings, calls missing any of the four citation fields, and gate decisions with no cited reading. A new interface query renders the full citation table; a new counterexample proves the shapes bite.</p>
# <p style="text-align:left"><strong>6. design note: categories over numerical ranges</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">the suggestion that this system prefer categories over numerical ranges as their interface contract and let the numerical precision live inside the oracles or within well documented threshold rules.</blockquote>
# <p style="text-align:left"><em>Changed:</em> the raw numerics remain exactly as the manifest states them (GATE-01 and GATE-02 evaluate the literal 0.80 and 0.25 comparisons); the category layer (RiskLevel, ConfidenceLevel) is the preferred interface; INTERFACE-01 is the documented threshold rule mapping number to category; the numbers themselves are oracle-provided (GAP-05). This note is a suggestion about the system&#x27;s design, available to raise with the author; it changes no verbatim rendering of the source text.</p>
# <p style="text-align:left"><strong>7. design note: parameters factored</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">numerical parameters in policies need to be factored out as parameters. this is part of what the implementation can do easily that a whitepaper cannot.</blockquote>
# <p style="text-align:left"><em>Changed:</em> the thresholds became single-point definitions (ValidationStrategyParameters: confidenceThreshold = 0.80, consensusDisagreementThreshold = 0.25, vendorRiskTrigger = high) that GATE-01, GATE-02, GATE-04, and INTERFACE-01 reference; outside verbatim doc quotes each literal appears exactly once, enforced by test. The Track records the parameter values in force per run — section 5.3&#x27;s &quot;the model versions and configuration parameters&quot; made executable — and an execution that omits them fails the shapes.</p>
# <p style="text-align:left"><strong>8. GAP-06, and the assembly directive</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">this reveals that we need to account for aggregate outputs. we successfully navigated the rules but the aggregate is no-op. which is different than successfully navigating the rules and executing. my intuition is that we&#x27;ve severely underutilitized the opensysml tool for its ability to define abstract and concrete parts, then wire them together along ports. this is what allows us to assemble complex workflows with both component level checks, wiring level checks, and system level checks with one toolchain</blockquote>
# <p style="text-align:left"><em>Changed:</em> the Op became an assembly of abstract/concrete parts wired along ports (oracles, policy engine, counterparty action, summary cog), with checks at three levels in one toolchain: the verbatim gates at component level; seam integrity at wiring level (WIRE-01..04 in satisfy, structural conformance in code over the conversion — validate accepts a mismatched connect, probed); obligations-discharged, stop-means-no-output (section 5.2 verbatim), and aggregate-outcome coherence at system level. AggregateOutcome {executed, noOp} names the distinction; the assembly&#x27;s lifecycle (running to stopped or completed) runs under trace. GAP-07 and GAP-08 were logged open by the same review.</p>
# <p style="text-align:left"><strong>9. GAP-07</strong> (2026-09-04, mzargham)</p>
# <blockquote style="text-align:left">we need it to be conditional but we should flag that we&#x27;ve made that judgement and acknowledge it departs from pinned draft</blockquote>
# <p style="text-align:left"><em>Changed:</em> final_output retention is now conditional on the aggregate outcome: an executed run&#x27;s Track must retain it; a noOp run&#x27;s Track must not carry one. Encoded as SPARQL constraints in shapes/track.shapes.ttl, whose violation messages acknowledge the departure from
# log entries rendered: 28 — 19 rulings, 9 notes

# %% [markdown]
# ## From code back to judgment
#
# Traceability runs the full chain: from any implemented artifact, back
# to the ruling it derives from, to the named adjudicator and date, to
# the open question that ruling resolved, to the gap's locator in the
# pinned source. Each anchor below is verified by the test suite to
# resolve into its file:

# %%
exhibits.show_judgment_trace()
# Out:
# <table>
# <thead><tr><th>Implementation</th><th>File</th><th>Derived from ruling</th><th>Resolves gap</th></tr></thead>
# <tbody>
# <tr><td style="text-align:left">enum def AggregateOutcome {executed, noOp}</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap06 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-06 @ §4.5, §5.2</code></td></tr>
# <tr><td style="text-align:left">the boundary stated where the outcome is defined: AggregateOutcome and AnomalySummaryCog docs</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap07-boundary (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-07 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">the noOp shape message: the Track is the internal record; final_output is the external action output</td><td style="text-align:left"><code>shapes/track.shapes.ttl</code></td><td style="text-align:left"><code>ruling-gap07-boundary (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-07 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">conditional final_output retention, with the departure acknowledged in the shape messages</td><td style="text-align:left"><code>shapes/track.shapes.ttl</code></td><td style="text-align:left"><code>ruling-gap07 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-07 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">enum def ConfidenceLevel {high, low, unknown}</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap03 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-03 @ §5.6, §5.1</code></td></tr>
# <tr><td style="text-align:left">CounterpartyAction: the discharging actor is unspecified where the manifest does not name a human</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap09 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-09 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">enum def DenominatorBasis: each metric declares what its value is a fraction of</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap11 (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-11 @ §5.6, §5.5</code></td></tr>
# <tr><td style="text-align:left">the requirement set&#x27;s one reading-independent satisfying state, pinned by enumeration</td><td style="text-align:left"><code>tests/test_requirement_directionality.py</code></td><td style="text-align:left"><code>ruling-gap10 (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-10 @ §5.6</code></td></tr>
# <tr><td style="text-align:left">abstract part def DisagreementMetric + three type-satisfying concretes</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap04 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-04 @ §5.6, §5.5</code></td></tr>
# <tr><td style="text-align:left">vfr:discharges + prov:generated in the run record: a discharging action mutates state</td><td style="text-align:left"><code>track/run-001.trig</code></td><td style="text-align:left"><code>ruling-gap02 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-02 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">DischargingActionShape: obligations must be discharged by recorded, state-mutating actions</td><td style="text-align:left"><code>shapes/track.shapes.ttl</code></td><td style="text-align:left"><code>ruling-gap02 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-02 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">the degenerate worked example: everything escalated, nothing emitted, and it passes</td><td style="text-align:left"><code>chapters/03-worked-examples.ipynb</code></td><td style="text-align:left"><code>ruling-gap10 (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-10 @ §5.6</code></td></tr>
# <tr><td style="text-align:left">the corrected who-acts annotation: three of four actions paper-named human</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap09-extension (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-09 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">gate decisions tied to the readings they cite, both directions, against the parameters in force</td><td style="text-align:left"><code>shapes/track.shapes.ttl</code></td><td style="text-align:left"><code>review-dsg-2 (reviewer-dsg-2, 2026-09-05)</code></td><td style="text-align:left"><code>external review finding (no gap: a repair the review drove)</code></td></tr>
# <tr><td style="text-align:left">governance query requires a named accountable party, not manual mode</td><td style="text-align:left"><code>queries/governance.rq</code></td><td style="text-align:left"><code>ruling-gap09-extension (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-09 @ §5.6, §5.2</code></td></tr>
# <tr><td style="text-align:left">the interface query rendering the full citation per gate variable</td><td style="text-align:left"><code>queries/interface.rq</code></td><td style="text-align:left"><code>ruling-gap05 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-05 @ §5.6</code></td></tr>
# <tr><td style="text-align:left">INTERFACE-01: the documented threshold rule binding number to category</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap03 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-03 @ §5.6, §5.1</code></td></tr>
# <tr><td style="text-align:left">the Learning purpose as a calibration view: signals mapped to the adaptation surface</td><td style="text-align:left"><code>exhibits.py</code></td><td style="text-align:left"><code>note-learning (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>design note (no gap: a recorded suggestion)</code></td></tr>
# <tr><td style="text-align:left">the worked calibration: unknown treated as high under a conservative variant</td><td style="text-align:left"><code>exhibits.py</code></td><td style="text-align:left"><code>note-unknown-conservative (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>design note (no gap: a recorded suggestion)</code></td></tr>
# <tr><td style="text-align:left">learning query carries the gate linkage each signal calibrates through</td><td style="text-align:left"><code>queries/learning.rq</code></td><td style="text-align:left"><code>note-learning (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>design note (no gap: a recorded suggestion)</code></td></tr>
# <tr><td style="text-align:left">the assembly lifecycle (running to stopped or completed) exercised under trace</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap06 (mzargham, 2026-09-04)</code></td><td style="text-align:left"><code>GAP-06 @ §4.5, §5.2</code></td></tr>
# <tr><td style="text-align:left">ConsensusInadequacyMetric with DisagreementMetric and UndecodabilityMetric branches, properties as attributes</td><td style="text-align:left"><code>model/vendor-fraud-review.sysml</code></td><td style="text-align:left"><code>ruling-gap04-class-split (mzargham, 2026-09-05)</code></td><td style="text-align:left"><code>GAP-04 @ §5.6, §5.5</code></td></tr>
# <tr><td style="text-align:left">MetricInputShape: a named metric without its matrix is refused</td><td style="text-align:left"><code>shapes/track.shapes.ttl</code></td><td style="text-align:left"><code>ruling-gap
# traceable implementations: 52 (each: implementation -> ruling -> named adjudicator -> gap -> pinned source)

# %% [markdown]
# ## The record is held to its own discipline
#
# The same treatment the Track gets applies to the judgment layer: shapes
# require every gap to be characterized and resolved, every ruling to be
# attributed and dated, every implementation to name its ruling and carry
# a resolvable anchor. A ruling without a named adjudicator is refused,
# because judgment enters the record only when someone owns it:

# %%
exhibits.check_adjudication_record()
# Out:
# the record (12 gaps, 19 rulings, 52 implementations) conforms: True
# unattributed-ruling counterexample   conforms: False
#   A ruling must name its adjudicator (prov:wasAttributedTo): judgment is attributed, never anonymous.

# %% [markdown]
# One entry shows the range an adjudication can take: GAP-04 is
# adjudicated like the rest — the decisions needed to render the rule
# implementable were made — but the ruling's content was to define the
# metric as a class: fix the type signature, deliberately specify the
# binding only at that level, and exhibit three type-satisfying
# examples (the previous chapter runs them; one deferral, one resolution,
# and three refinements are on record, the last two after the second
# external review split the class and fixed the matrix's shape). The gap closed all the same; the
# ruling simply took a different approach, not a different kind of
# response. Correctly
# constructed is not the same as fit for purpose, and the concrete choice
# belongs to a policy designer, not to a translation.
#
# The record is the only artifact: this chapter's tables, the
# characterizations, and the rulings all render from
# `open-questions/adjudications.ttl`. The hand-written prose of the
# judgment layer lives in that one file, as annotation, and nowhere
# else.
#
# ## The checks
#
# One script runs everything shown in these chapters plus the full test
# suite: the pinned toolchain, strict validation, the satisfy sweep, the
# counterexamples that must fail, byte-identical regeneration of the
# converted artifacts, the site build, and every test (including the one
# that re-executes these chapters and compares the outputs). The latest
# outcomes:

# %%
exhibits.show_checks_outcomes()
# Out:
# pass  toolchain: pinned sysml, checksum-verified
# pass  model: validate -strict
# pass  model: satisfy RunConfigurations
# pass  counterexample: unattended run must fail satisfy
# pass  generated/ regenerates byte-identically
# pass  site: myst build --html
# pass  tests: full suite
# result: PASS
